# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import joblib

# %%
df = pd.read_csv("Mall_Customers.csv")

print("Dataset Shape:", df.shape)

display(df.head())

print("\nDataset Information:")
df.info()

print("\nStatistical Summary:")
display(df.describe())

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Dataset Shape: (200, 5)
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    str
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), str(1)
# ...

# %%
features = [
    'Age',
    'Annual Income (k$)',
    'Spending Score (1-100)'
]

X = df[features]

print("Features used:")
print(features)
# Out:
# Features used:
# ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("Data scaling completed.")
# Out:
# Data scaling completed.

# %%
inertia = []

for k in range(1, 11):
    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))

plt.plot(range(1, 11), inertia, marker='o')

plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal K")

plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
kmeans = KMeans(
    n_clusters=5,
    random_state=42,
    n_init=10
)

clusters = kmeans.fit_predict(X_scaled)

df['Cluster'] = clusters

print("K-Means clustering completed.")

display(df.head())
# Out:
# K-Means clustering completed.
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1

# %%
plt.figure(figsize=(9, 6))

plt.scatter(
    df['Annual Income (k$)'],
    df['Spending Score (1-100)'],
    c=df['Cluster'],
    s=60
)

plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.title("Customer Segmentation using K-Means")

plt.show()

# %%
plt.figure(figsize=(9, 6))

plt.scatter(
    df['Age'],
    df['Spending Score (1-100)'],
    c=df['Cluster'],
    s=60
)

plt.xlabel("Age")
plt.ylabel("Spending Score (1-100)")
plt.title("Customer Groups by Age and Spending Score")

plt.show()

# %%
cluster_summary = df.groupby('Cluster')[features].mean().round(2)

print("Average values for each customer cluster:")
display(cluster_summary)
# Out:
# Average values for each customer cluster:
#            Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0        46.25               26.75                   18.35
# 1        25.19               41.09                   62.24
# 2        32.88               86.10                   81.53
# 3        39.87               86.10                   19.36
# 4        55.64               54.38                   48.85

# %%
spending_means = df.groupby('Cluster')['Spending Score (1-100)'].mean()

sorted_clusters = spending_means.sort_values().index.tolist()

labels = {}

for i, cluster in enumerate(sorted_clusters):
    if i == 0:
        labels[cluster] = "Low Spenders"
    elif i == len(sorted_clusters) - 1:
        labels[cluster] = "High Spenders"
    else:
        labels[cluster] = "Medium Spenders"

df['Customer Segment'] = df['Cluster'].map(labels)

display(df.head(10))
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72
#
#    Cluster Customer Segment
# 0        1  Medium Spenders
# 1        1  Medium Spenders
# 2        0     Low Spenders
# 3        1  Medium Spenders
# 4        1  Medium Spenders
# ...

# %%
print("Customer Segment Distribution:")

print(df['Customer Segment'].value_counts())

plt.figure(figsize=(8, 5))

df['Customer Segment'].value_counts().plot(kind='bar')

plt.xlabel("Customer Segment")
plt.ylabel("Number of Customers")
plt.title("Customer Segment Distribution")

plt.xticks(rotation=0)

plt.show()
# Out:
# Customer Segment Distribution:
# Customer Segment
# Medium Spenders    140
# High Spenders       40
# Low Spenders        20
# Name: count, dtype: int64

# %%
final_summary = df.groupby('Customer Segment')[features].mean().round(2)

display(final_summary)
# Out:
#                     Age  Annual Income (k$)  Spending Score (1-100)
# Customer Segment
# High Spenders     32.88               86.10                   81.53
# Low Spenders      46.25               26.75                   18.35
# Medium Spenders   39.50               58.09                   45.80

# %%
df.to_csv("Mall_Customers_Segmented.csv", index=False)

print("Segmented customer dataset saved successfully.")
# Out:
# Segmented customer dataset saved successfully.

# %%
joblib.dump(kmeans, "customer_segmentation_model.pkl")
joblib.dump(scaler, "customer_scaler.pkl")

print("K-Means model and scaler saved successfully.")
# Out:
# K-Means model and scaler saved successfully.

# %%
loaded_kmeans = joblib.load("customer_segmentation_model.pkl")
loaded_scaler = joblib.load("customer_scaler.pkl")

print("Model and scaler loaded successfully.")
# Out:
# Model and scaler loaded successfully.
